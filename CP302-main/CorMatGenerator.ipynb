# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data1=pd.read_excel('Processed Data\Intrinsic Data.xlsx', sheet_name=0, usecols="B:E,H:I")
data2=pd.read_excel('Processed Data\Extrinsic Data.xlsx', sheet_name=0, usecols="B:P")
data1.corr()
data2.corr()
# Out:
# C:\Users\ADITYA\AppData\Local\Temp\ipykernel_4588\3410594711.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data1.corr()
# C:\Users\ADITYA\AppData\Local\Temp\ipykernel_4588\3410594711.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data2.corr()
#                                  Green Fodder given \nto in milk  \
# Green Fodder given \nto in milk                         1.000000
# Dry Fodder given to\n in milk                          -0.478234
# Max T                                                   0.163613
# Min T                                                   0.148326
# ...

# %%
sns.heatmap(data1.corr(),annot=True,vmin=-1,vmax=1,center=0,cmap='vlag')
# Out:
# C:\Users\ADITYA\AppData\Local\Temp\ipykernel_4588\930059048.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data1.corr(),annot=True,vmin=-1,vmax=1,center=0,cmap='vlag')
# <Axes: >

# %%
data2 = data2.drop('Max T', axis=1)
data2 = data2.drop('Min T', axis=1)
sns.heatmap(data2.corr(),annot=True,vmin=-1,vmax=1,center=0,cmap='vlag')
# Out:
# C:\Users\ADITYA\AppData\Local\Temp\ipykernel_4588\2602818602.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data2.corr(),annot=True,vmin=-1,vmax=1,center=0,cmap='vlag')
# <Axes: >

# %%
matrix=data1.corr()
mask=np.triu(np.ones_like(matrix,dtype=bool))
matrix2=data2.corr()
mask2=np.triu(np.ones_like(matrix2,dtype=bool))
# Out:
# C:\Users\ADITYA\AppData\Local\Temp\ipykernel_4588\2382720766.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matrix=data1.corr()
# C:\Users\ADITYA\AppData\Local\Temp\ipykernel_4588\2382720766.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matrix2=data2.corr()

# %%
sns.heatmap(data1.corr(),annot=True,vmin=-1,vmax=1,center=0,cmap='vlag',mask=mask)
# Out:
# C:\Users\ADITYA\AppData\Local\Temp\ipykernel_4588\3571924850.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data1.corr(),annot=True,vmin=-1,vmax=1,center=0,cmap='vlag',mask=mask)
# <Axes: >

# %%
sns.heatmap(data2.corr(),annot=True,vmin=-1,vmax=1,center=0,cmap='vlag',mask=mask2)
# Out:
# C:\Users\ADITYA\AppData\Local\Temp\ipykernel_4588\1099696799.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data2.corr(),annot=True,vmin=-1,vmax=1,center=0,cmap='vlag',mask=mask2)
# <Axes: >
