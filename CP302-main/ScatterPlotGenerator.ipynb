# %%
import pandas as pd
import matplotlib.pyplot as plt

data1=pd.read_excel('Processed Data\Intrinsic Data.xlsx', sheet_name=0, usecols="B:E,H:I")
data2=pd.read_excel('Processed Data\FarmMilkProdperCattle.xlsx', sheet_name=0, usecols="B:Q")

data1.plot.scatter(x='Age', y='Milk Production/Day')
plt.xlabel('Age')
plt.ylabel('Milk Production/Day')
plt.title('Milk Production/Day vs Age')
plt.show()

# %%
data1.plot.scatter(x='Parity/Lactation no.', y='Milk Production/Day')
plt.xlabel('Parity/Lactation no.')
plt.ylabel('Milk Production/Day')
plt.title('Milk Production/Day vs Parity/Lactation no.')
plt.show()

# %%
data1.plot.scatter(x='Age of 1st Calving', y='Milk Production/Day')
plt.xlabel('Age of 1st Calving')
plt.ylabel('Milk Production/Day')
plt.title('Milk Production/Day vs Age of 1st Calving')
plt.show()

# %%
data1.plot.scatter(x='Breed', y='Milk Production/Day')
plt.xlabel('Breed')
plt.ylabel('Milk Production/Day')
plt.title('Milk Production/Day vs Breed')
plt.show()

# %%
print(data2)
data2.plot.scatter(x='Month', y='FarmMilkPerCattle')
plt.xlabel('Month')
plt.ylabel('Milk Production')
plt.title('Milk Production vs Month')
plt.show()
# Out:
#       Month  Green Fodder given \nto in milk  Dry Fodder given to\n in milk  \
# 0     April                               33                            3.0
# 1      May                                30                            4.0
# 2       Jun                               33                            3.0
# 3      July                               33                            3.0
# 4       Aug                               35                            2.5
# ...     ...                              ...                            ...
# 5904  April                               33                            4.0
# 5905    Feb                               34                            6.0
# 5906    Sep                               34                            3.0
# 5907    Aug                               36                            3.0
# 5908  April                               33                            3.0
#
# ...

# %%
print(data2)
print(data2.columns)
data2.plot.scatter(x='Month', y='FarmMilkPerCattle')
plt.xlabel('Month')
plt.ylabel('Milk Production')
plt.title('Milk Production vs Month')
plt.show()
# Out:
#       Month  Green Fodder given \nto in milk  Dry Fodder given to\n in milk  \
# 0     April                               33                            3.0
# 1      May                                30                            4.0
# 2       Jun                               33                            3.0
# 3      July                               33                            3.0
# 4       Aug                               35                            2.5
# ...     ...                              ...                            ...
# 5904  April                               33                            4.0
# 5905    Feb                               34                            6.0
# 5906    Sep                               34                            3.0
# 5907    Aug                               36                            3.0
# 5908  April                               33                            3.0
#
# ...

# %%
data2.plot.scatter(x='Green Fodder given \nto in milk', y='FarmMilkPerCattle')
plt.xlabel('Green Fodder given')
plt.ylabel('Milk Production')
plt.title('Milk Production vs Green Fodder given')
plt.show()

# %%
data2.plot.scatter(x='Dry Fodder given to\n in milk', y='FarmMilkPerCattle')
plt.xlabel('Dry Fodder given')
plt.ylabel('Milk Production')
plt.title('Milk Production vs Dry Fodder given')
plt.show()

# %%
data2.plot.scatter(x='Max T', y='FarmMilkPerCattle')
plt.xlabel('Max T')
plt.ylabel('Milk Production')
plt.title('Milk Production vs Max T')
plt.show()

# %%
data2.plot.scatter(x='Min T', y='FarmMilkPerCattle')
plt.xlabel('Min T')
plt.ylabel('Milk Production')
plt.title('Milk Production vs Min T')
plt.show()

# %%
data2.plot.scatter(x='Mean T', y='FarmMilkPerCattle')
plt.xlabel('Mean T')
plt.ylabel('Milk Production')
plt.title('Milk Production vs Mean T')
plt.show()

# %%
data2.plot.scatter(x='RH', y='FarmMilkPerCattle')
plt.xlabel('RH')
plt.ylabel('Milk Production')
plt.title('Milk Production vs RH')
plt.show()

# %%
data2.plot.scatter(x='Rainfall', y='FarmMilkPerCattle')
plt.xlabel('Rainfall')
plt.ylabel('Milk Production')
plt.title('Milk Production vs Rainfall')
plt.show()

# %%
data2.plot.scatter(x='THI', y='FarmMilkPerCattle')
plt.xlabel('THI')
plt.ylabel('Milk Production')
plt.title('Milk Production vs THI')
plt.show()

# %%
data2.plot.scatter(x='farm size ', y='FarmMilkPerCattle')
plt.xlabel('farm size')
plt.ylabel('Milk Production')
plt.title('Milk Production vs farm size ')
plt.show()

# %%
data2.plot.scatter(x='District', y='FarmMilkPerCattle')
plt.xlabel('District')
plt.ylabel('Milk Production')
plt.title('Milk Production vs District')
plt.show()

# %%
data2.plot.scatter(x='Zone', y='FarmMilkPerCattle')
plt.xlabel('Zone')
plt.ylabel('Milk Production')
plt.title('Milk Production vs Zone')
plt.show()

# %%
data2.plot.scatter(x='Green \nFodder', y='FarmMilkPerCattle')
plt.xlabel('Green Fodder')
plt.ylabel('Milk Production')
plt.title('Milk Production vs Green Fodder')
plt.show()

# %%
data2.plot.scatter(x='Dry\n Fodder', y='FarmMilkPerCattle')
plt.xlabel('Dry Fodder')
plt.ylabel('Milk Production')
plt.title('Milk Production vs Dry Fodder')
plt.show()
